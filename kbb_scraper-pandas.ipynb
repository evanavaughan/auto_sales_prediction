# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import csv

# %%
site= 'https://www.kbb.com/car-finder/?categories=sedan&years=2006-2020'
site2 = 'https://www.kbb.com/car-finder/2/?categories=sedan&years=2006-2020'
sites = [site, site2]
page = 'https://www.kbb.com/audi/a5/2016/'

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException

# %%
def scraper(lst, start, stop):
    listings = []
    for i in lst[start:stop]:

        chrome_options = webdriver.ChromeOptions()
        prefs = {"profile.managed_default_content_settings.images": 2}
        chrome_options.add_experimental_option("prefs", prefs)

        driver = webdriver.Chrome(options=chrome_options)
        driver.get(i)

        try:
            element = r'//*[@id="content"]/main/div[5]/div[2]/section/a[1]'
            href = element.get_attribute('href')
            listings.append(href)
        
        except (NoSuchElementException, ValueError, AttributeError):
            review = 'n/a'
        
        driver.close()
    return listings

# %%
x = scraper(sites, 0,2)

# %%
//*[@id="content"]/main/div[4]/div[2]/section/a[2]

# %%
def webpage_html(self, url):
    nyc_request = requests.get(url)
    self.trip_advisor_html = nyc_request.text
    return self.trip_advisor_html

# %%
class Scraper:
    def webpage_html(self, url):
        nyc_request = requests.get(url)
        self.trip_advisor_html = nyc_request.text
        return self.trip_advisor_html

    def listing_page(self, trip_advisor_html = None):
        trip_advisor_html = trip_advisor_html or self.trip_advisor_html
        ta_soup = BeautifulSoup(trip_advisor_html)
        self.individual_listing =  ta_soup.findAll('a', {'class': 'css-1p68pse'})
        return self.individual_listing

# %%
bob = Scraper()

# %%
bob.webpage_html(site)
# Out:
# '<!doctype html><html lang="en"><head><meta http-equiv="X-UA-Compatible" content="IE=edge"><meta charset="utf-8"><meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1,minimum-scale=1,user-scalable=no"><link rel="shortcut icon" href="https://static.kbb.com/research/master/prod/favicon.ico"><script src="//assets.adobedtm.com/launch-EN3501a880262842d897b6a61bbd934a4d.min.js" async></script><title data-rh="true">Car Finder  | Find Your Perfect Car | Kelley Blue Book</title><meta data-rh="true" name="description" content="Want to find the perfect car? Use the Kelley Blue Book car finder to filter and sort by the features and specifications most important to you. Browse by price, MPG, new/used, category, style, and many more!. "/><link data-rh="true" rel="canonical" href="https://www.kbb.com/car-finder/"/><script data-rh="true" async="true" type="text/javascript" src="https://z.moatads.com/kbbprebidheader788495884989/yi.js"></script><script data-rh="true" type="application/ld+json">\n            {\n              "@context": "http://schema.org",\n              "@type": "WebSite",\n              "name": "Kelley Blue Book",\n              "alternateName":  "KBB",\n              "url": "https://www.kbb.com/"\n            }\n          </script></head><body><div id="root"><style data-emotion-css="hmi90k 1u5lfxb qnx973 1h63rdn 1yq1zu7 vuex56">*,*::before,*::after{box-sizing:border-box;}html{min-height:100%;}body{box-sizing:border-box;color:#111111;font-family:sans-serif,Tahoma,Arial;line-height:1.5;margin:0;min-height:100%;}body.font-loaded{font-family:"Open Sans",sans-serif,Tahoma,Arial;}*,*::before,*::after{box-sizing:border-box;}html{min-height:100%;}body{box-sizing:border-box;color:#111111;font-family:sans-serif,Tahoma,Arial;line-height:1.5;margin:0;min-height:100%;}body.font-loaded{font-family:"Open Sans",sans-serif,Tahoma,Arial,sans-serif,Tahoma,Arial;}@-webkit-keyframes animation-qnx973{0%{-webkit-transform:scale(0);-ms-transform:scale(0);transform:scale(0);}100%{-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);}}@keyframes animation-qnx973{0%{-webkit-transform:scale(0);-ms-transform:scale(0);transform:scale(0);}100%{-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);}}@-webkit-keyframes animation-1h63rdn{0%{-webkit-transform:translate(0,0);-ms-transform:translate(0,0);transform:translate(0,0);}100%{-webkit-transform:translate(19px,0);-ms-transform:translate(19px,0);transform:translate(19px,0);}}@keyframes animation-1h63rdn{0%{-webkit-transform:translate(0,0);-ms-transform:translate(0,0);transform:translate(0,0);}100%{-webkit-transform:translate(19px,0);-ms-transform:translate(19px,0);transform:translate(19px,0);}}@-webkit-keyframes animation-1yq1zu7{0%{-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);}100%{-webkit-transform:scale(0);-ms-transform:scale(0);transform:scale(0);}}@keyframes animation-1yq1zu7{0%{-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);}100%{-webkit-transform:scale(0);-ms-transform:scale(0);transform:scale(0);}}body::before{background-color:transparent;}</style><style data-emotion-css="1npz73d">body{font-family:\'Open Sans\',sans-serif,Tahoma,Arial;font-size:14px;margin:0;min-height:100%;}</style><style data-emotion-css="1j5y8p7">*::before,*::after{box-sizing:border-box;}body{background:#1e3b6f;background:linear-gradient(to right,#1e3b6f 0%,#2989d8 25%,#207cca 75%,#1e3b6f 100%);border:0;box-sizing:border-box;font-weight:normal;height:100%;-webkit-letter-spacing:0;-moz-letter-spacing:0;-ms-letter-spacing:0;letter-spacing:0;line-height:1.5;padding:0;position:relative;vertical-align:baseline;}body::before{background-color:#fff;bottom:0;content:\'\';display:block;left:50%;margin-left:-499px;max-width:100vw;position:absolute;top:0;width:998px;z-index:-1;}</style><style data-emotion-css="13skz42">@font-face{font-family:\'Open Sans\';font-style:normal;font-weight:700;font-display:swap;src:local(\'Open Sans Bold\'), ...

# %%
prefix = 'https://www.kbb.com/car-finder/'
suffix = '/?categories=sedan&years=2006-2020'

# %%
def scrape(pre, suf):
    urls = []
    for i in range(1,139):
        site  = pre + str(i) + suf
        html = requests.get(site).text
        soup = BeautifulSoup(html, 'lxml')
        for link in soup.find_all('a'):
            urls.append(link.get('href'))
    cleaned_list = [clean(url) for url in urls if url.startswith('https://staging')]
    return cleaned_list

# %%
listy = scrape(prefix, suffix)

# %%
listy{}

# %%
def clean(url):
    url = url.replace('staging.', '')
    sep = '?'
    return url.split(sep, 1)[0]

# %%
new_list = [clean(url) for url in urls if url.startswith('https://staging')]
